# %% [markdown]
# # SupplyMind AI — Champion Explainability

# %%
# -------------------
# Imports
# -------------------

from supplymind.features.predictions.ml.artifacts import load_model_artifact
from supplymind.features.predictions.ml.reporting import save_feature_importance

# %%
# -------------------
# Project configuration
# -------------------

from pathlib import Path

DATASET_PATH = Path("../data/raw/syndelay/syndelay_v1.csv")
REPORT_ROOT = Path("../reports")
MODEL_ROOT = Path("../models")

assert DATASET_PATH.exists(), (
    f"Dataset not found at {DATASET_PATH}. "
    "Place syndelay_v1.csv under data/raw/syndelay/."
)

# %%
# -------------------
# Load champion
# -------------------

champion, metadata = load_model_artifact(MODEL_ROOT / "champion")

metadata
# Out:
# {'model_name': 'random_forest',
#  'model_version': '1.0.0',
#  'trained_at': '2026-08-11T11:45:16.917646+00:00',
#  'threshold': 0.3000000000000001,
#  'selection_metric': 'validation_f1_then_recall_then_roc_auc',
#  'validation_metrics': {'model_name': 'random_forest',
#   'accuracy': 0.5825151138361274,
#   'precision': 0.5813780748896754,
#   'recall': 0.9884118258802556,
#   'f1': 0.732124680183774,
#   'roc_auc': 0.7382135227425288,
#   'average_precision': 0.8338696672202058,
#   'true_negative': 280,
#   'false_positive': 9581,
#   'false_negative': 156,
#   'true_positive': 13306,
#   'threshold': 0.3000000000000001,
#   'training_seconds': 234.17919719300698},
#  'test_metrics': {'accuracy': 0.5826616360830046,
#   'precision': 0.5824151801329136,
#   'recall': 0.9864484597156398,
#   'f1': 0.7324059819661315,
#   'roc_auc': 0.7391576743347072,
#   'average_precision': 0.8313380369635426,
#   'true_negative': 269,
#   'false_positive': 9551,
#   'false_negative': 183,
#   'true_positive': 13321,
#   'threshold': 0.3000000000000001},
#  'source_dataset': 'SynDelay v1',
#  'target': {'source_column': 'label',
#   'canonical_column': 'is_delayed',
#   'mapping': {'0_early': 0, '1_on_time': 0, '2_delayed': 1}}}

# %%
# -------------------
# Global feature importance
# -------------------

importance = save_feature_importance(
    champion,
    REPORT_ROOT / "models" / "champion" / "feature_importance",
    top_n=30,
)

importance.head(30) if importance is not None else "No native importance."
# Out:
#                          feature  importance
# 0   shipping_mode_Standard Class    0.157289
# 1      shipping_mode_First Class    0.120862
# 2     shipping_mode_Second Class    0.045771
# 3                       latitude    0.030664
# 4               profit_per_order    0.030344
# 5         order_profit_per_order    0.029722
# 6                      longitude    0.029213
# 7             sales_per_customer    0.028206
# 8           order_city_frequency    0.027830
# 9        order_item_profit_ratio    0.026284
# 10         order_state_frequency    0.026101
# 11       order_item_total_amount    0.025054
# 12           order_item_discount    0.024937
# 13                     order_day    0.024838
# 14                    order_week    0.024302
# 15                    order_hour    0.023598
# 16      order_item_discount_rate    0.020408
# 17       customer_city_frequency    0.019765
# 18                   order_month    0.016511
# 19                 order_weekday    0.015930
# 20                         sales    0.013419
# 21        shipping_mode_Same Day    0.010430
# 22                 product_price    0.009712
# 23      order_item_product_price    0.009621
# 24                 order_quarter    0.008533
# 25                    order_year    0.008493
# 26           order_item_quantity    0.007333
# 27     customer_segment_Consumer    0.005502
# 28            payment_type_DEBIT    0.005036
# 29    customer_segment_Corporate    0.005027
