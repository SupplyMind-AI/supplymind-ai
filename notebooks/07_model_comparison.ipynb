# %% [markdown]
# # SupplyMind AI — Model Comparison
#
# This notebook is scaffolded for the next step after the baseline is stable.
#
# Approved V1 candidates:
#
# - Logistic Regression
# - Random Forest
# - XGBoost
# - HistGradientBoosting, only if time permits
#
# Model selection must use validation F1 and delayed-class recall.
# The untouched test set is evaluated only once for the selected champion.

# %%
# -------------------
# Next step
# -------------------

# Reuse the same:
# - cleaned dataset
# - eligible feature list
# - chronological split
# - preprocessing contract
# - evaluation function
#
# Only the estimator should change.
